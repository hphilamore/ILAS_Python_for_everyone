# %% [markdown]
# # Assignment
# ### Assessment Part 1 : Game Project
#
# Using the skills you have learnt, design and build a sinple computer game.
#
# 50% of final grade.
#
# Submission date : 2018/07/17, (July 17, Tuesday)

# %% [markdown]
# ###  Game Project : Requirements
#
# 1. Design your game : what is the goal?
# 1. Use programming skills to build your game:
#     - use variables to store values
#     - write you code efficiently and use functions from libraries e.g. pygame, math to make code more concise
#     - use the computer's physical interfaces
#     - use functions to avoid repetition
#     - input and output data from your program (e.g. python code, text file (high score), image (player), sound (background music).

# %% [markdown]
# ###  How to design your game
#
# Today's homework is to plan your game.
#
# You need:
# 1. A theme
# 1. A basic plan

# %%
import io
import base64
from IPython.display import HTML

# %% [markdown]
# __Example...__

# %%
video = io.open('img/pygame-tutorials.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video width = "500"  alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video width = "500"  alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# __Example__
#
# __Theme : __ Boxes fall from the sky. The player moves the car. The goal is to not get hit by the falling boxes.
#
# __Plan : __
# - Rectangle shape will move from top to bottom of window, at random.
# - Keyboard left and right will be used to move the car.
# - If the car is hit, the game stops.
# - The user can choose to play again by clicking "play again" or "quit" button.

# %% [markdown]
# Please submit theme and plan before attending the recheduled class.

# %% [markdown]
# *Laberlabs, Danny Schmidt and Tea Blumer*
#
# ### Your game can be about anything you want.
#
# <table>
#     <tr>
#     <td> <img src="img/flying_squirrels.jpg" alt="Drawing" style="width: 200px;"/> </td>
#     <td> <img src="img/laser_foxes.jpg" alt="Drawing" style="width: 200px;"/> </td>
#     </tr>
# </table>

# %% [markdown]
# ### Rescheduled Class
# <br>Rescheduled classes will be held on:
#
# - 06/25 (June 25, Monday), period 1, CALL 23
# - 06/26 (June 26, Tuesday), period 2 and 3, CALL 21
#
# These classes are for you to ask questions and get help with starting your game projects.
#
# There will be no new taught material in these classes.
#
# __THERE IS A CLASS ON JUNE 26, TUESDAY AS USUAL__

# %%
### Rescheduled Class
<br>Rescheduled classes will be held on: 

- 06/25 (June 25, Monday), period 1, CALL 23
- 06/26 (June 26, Tuesday), period 2 and 3, CALL 21

These classes are for you to ask questions and get help with starting your game projects. 

There will be no new taught material in these classes.

__THERE IS A CLASS ON JUNE 26, TUESDAY AS USUAL__
